# %% [markdown]
# <a href="https://colab.research.google.com/github/khemchandra4/lp5/blob/main/movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import imdb
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
train_labels[0]
# Out:
# np.int64(1)

# %%
print(type([max(sequence) for sequence in train_data]))
# Find the maximum of all max indexes
max([max(sequence) for sequence in train_data])
# Out:
# <class 'list'>
# 9999

# %%
# step 1: load the dictionary mappings from word to integer index
word_index = imdb.get_word_index()
# step 2: reverse word index to map integer indexes to their respective words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
# Step 3: decode the review, mapping integer indices to words
# indices are off by 3 because 0, 1, and 2 are reserverd indices for "padding", "Start of se
decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in train_data[0]])
decoded_review
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
len(reverse_word_index)
# Out:
# 88584

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension)) # Creates an all zero matrix of shape
    for i,sequence in enumerate(sequences):
        results[i,sequence] = 1 # Sets specific indices of results[i]
    return results
# Vectorize training Data
X_train = vectorize_sequences(train_data)
# Vectorize testing Data
X_test = vectorize_sequences(test_data)

# %%
X_train[0]
X_train.shape
# Out:
# (25000, 10000)

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
optimizer=optimizers.RMSprop(learning_rate=0.001),
loss = losses.binary_crossentropy,
metrics = [metrics.binary_accuracy]
)

# %%
# Input for Validation
X_val = X_train[:10000]
partial_X_train = X_train[10000:]
# Labels for validation
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(
partial_X_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - binary_accuracy: 0.6698 - loss: 0.6158 - val_binary_accuracy: 0.8340 - val_loss: 0.4367
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - binary_accuracy: 0.8930 - loss: 0.3606 - val_binary_accuracy: 0.8693 - val_loss: 0.3381
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - binary_accuracy: 0.9156 - loss: 0.2634 - val_binary_accuracy: 0.8797 - val_loss: 0.3010
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - binary_accuracy: 0.9323 - loss: 0.2086 - val_binary_accuracy: 0.8864 - val_loss: 0.2805
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9450 - loss: 0.1717 - val_binary_accuracy: 0.8832 - val_loss: 0.2895
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9543 - loss: 0.1439 - val_binary_accuracy: 0.8844 - val_loss: 0.2805
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9628 - loss: 0.1251 - val_binary_accuracy: 0.8849 - val_loss: 0.2888
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - binary_accuracy: 0.9694 - loss: 0.1059 - val_binary_accuracy: 0.8840 - val_loss: 0.3067
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9759 - loss: 0.0913 - val_binary_accuracy: 0.8820 - val_loss: 0.3139
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9790 - loss: 0.0765 - val_binary_accuracy: 0.8812 - val_loss: 0.3300
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9853 - loss: 0.0640 - val_binary_accuracy: 0.8799 - val_loss: 0.3481
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - binary_accuracy: 0.9894 - loss: 0.0548 - val_binary_accuracy: 0.8726 - val_loss: 0.3839
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - binary_accuracy: 0.9902 - loss: 0.0479 - val_binary_accuracy: 0.8767 - val_loss: 0.3938
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - binary_accuracy: 0.9931 - loss: 0.0384 - val_binary_accuracy: 0.8759 - val_loss: 0.4064
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - binary_accuracy: 0.9949 - loss: 0.0326 - val_binary_accuracy: 0.8751 - val_loss: 0.4247
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - binary_accuracy: 0.9966 - loss: 0.0272 - val_binary_accuracy: 0.8707 - val_loss: 0.4586
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9970 - loss: 0.0241 - val_binary_accuracy: 0.8707 - val_loss: 0.4797
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9988 - loss: 0.0194 - val_binary_accuracy: 0.8708 - val_loss: 0.4972
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9985 - loss: 0.0173 - val_binary_accuracy: 0.8711 - val_loss: 0.5206
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9991 - loss: 0.0140 - val_binary_accuracy: 0.8720 - val_loss: 0.5443

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['binary_accuracy', 'loss', 'val_binary_accuracy', 'val_loss'])

# %%
# Plotting losses
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g', label="Training Loss")
plt.plot(epochs, val_loss_values, 'b', label="Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.show()

# %%
# Training and Validation Accuracy
acc_values = history_dict['binary_accuracy']
val_acc_values = history_dict['val_binary_accuracy']
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, acc_values, 'g', label="Training Accuracy")
plt.plot(epochs, val_acc_values, 'b', label="Validation Accuracy")
plt.title('Training and Validation Accuraccy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.fit(
partial_X_train,
partial_y_train,
epochs=3,
batch_size=512,
validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - binary_accuracy: 0.9996 - loss: 0.0102 - val_binary_accuracy: 0.8573 - val_loss: 0.6426
# Epoch 2/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - binary_accuracy: 0.9999 - loss: 0.0099 - val_binary_accuracy: 0.8674 - val_loss: 0.5910
# Epoch 3/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - binary_accuracy: 0.9994 - loss: 0.0084 - val_binary_accuracy: 0.8674 - val_loss: 0.6225

# %%
# Making Predictions for testing data
np.set_printoptions(suppress=True)
result = model.predict(X_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
result
# Out:
# array([[0.0051159 ],
#        [0.9999985 ],
#        [0.12472846],
#        ...,
#        [0.00055137],
#        [0.00303889],
#        [0.94685423]], dtype=float32)

# %%
y_pred = np.zeros(len(result))
for i, score in enumerate(result):
    y_pred[i] = np.round(score)
# Out:
# <ipython-input-20-d06888fff3d2>:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i] = np.round(score)

# %%
mae = metrics.mean_absolute_error(y_pred, y_test)
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.14336000382900238>
